# %% [markdown]
# <a href="https://colab.research.google.com/github/Jenciso20/Inicio-Cristiano/blob/main/Examen_segunda_unidad_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import datetime
import seaborn as sns
import numpy as np
# %matplotlib inline

# %% [markdown]
# Obtenemos los resultados de la siguiente pagina web:https://www.datosabiertos.gob.pe/dataset/dataset-resultado-de-linaje-genómico-de-pruebas-
# moleculares-del-instituto-nacional-de-salud

# %%
#1.Descargamos
# !ls
# Out:
# pmGenoma_27Sep2023.csv	sample_data

# %%
#mostramos el contenido
df = pd.read_csv('pmGenoma_27Sep2023.csv' , sep = ";")
df
# Out:
#                                              FECHA_CORTE  UUID  FECHA_MUESTRA  \
# 0                                               20230927   NaN     20210307.0
# 1                                               20230927   NaN     20210616.0
# 2                                               20230927   NaN     20210727.0
# 3                                               20230927   NaN     20211022.0
# 4                                               20230927   NaN     20211127.0
# ...                                                  ...   ...            ...
# 43167                                                NaN   NaN            NaN
# 43168                              (43167 rows affected)   NaN            NaN
# 43169                                                NaN   NaN            NaN
# 43170                                                NaN   NaN            NaN
# 43171  Completion time: 2023-09-27T08:18:56.5124153-0...   NaN            NaN
#
# ...

# %%
#Tipos de datos de las columnas y sus dimenciones
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 43172 entries, 0 to 43171
# Data columns (total 15 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   FECHA_CORTE            43169 non-null  object
#  1   UUID                   42993 non-null  float64
#  2   FECHA_MUESTRA          43167 non-null  float64
#  3   EDAD                   43157 non-null  float64
#  4   SEXO                   43167 non-null  object
#  5   INSTITUCION            43167 non-null  object
#  6   UBIGEO_PACIENTE        43167 non-null  float64
#  7   DEPARTAMENTO_PACIENTE  43167 non-null  object
#  8   PROVINCIA_PACIENTE     43167 non-null  object
#  9   DISTRITO_PACIENTE      43167 non-null  object
#  10  DEPARTAMENTO_MUESTRA   43167 non-null  object
#  11  PROVINCIA_MUESTRA      43167 non-null  object
#  12  DISTRITO_MUESTRA       43163 non-null  object
#  13  TIPO_MUESTRA           43167 non-null  object
# ...

# %%
df.isnull().sum()
# Out:
# FECHA_CORTE                3
# UUID                     179
# FECHA_MUESTRA              5
# EDAD                      15
# SEXO                       5
# INSTITUCION                5
# UBIGEO_PACIENTE            5
# DEPARTAMENTO_PACIENTE      5
# PROVINCIA_PACIENTE         5
# DISTRITO_PACIENTE          5
# DEPARTAMENTO_MUESTRA       5
# PROVINCIA_MUESTRA          5
# DISTRITO_MUESTRA           9
# TIPO_MUESTRA               5
# RESULTADO                  5
# dtype: int64

# %%
df = pd.read_csv('pmGenoma_27Sep2023.csv' , sep =";" , parse_dates=['FECHA_MUESTRA'])
df
# Out:
#                                              FECHA_CORTE  UUID FECHA_MUESTRA  \
# 0                                               20230927   NaN    2021-03-07
# 1                                               20230927   NaN    2021-06-16
# 2                                               20230927   NaN    2021-07-27
# 3                                               20230927   NaN    2021-10-22
# 4                                               20230927   NaN    2021-11-27
# ...                                                  ...   ...           ...
# 43167                                                NaN   NaN           NaT
# 43168                              (43167 rows affected)   NaN           NaT
# 43169                                                NaN   NaN           NaT
# 43170                                                NaN   NaN           NaT
# 43171  Completion time: 2023-09-27T08:18:56.5124153-0...   NaN           NaT
#
# ...

# %%
df['FECHA_CORTE'] = pd.to_datetime(df['FECHA_CORTE'], errors='coerce')
df
# Out:
#       FECHA_CORTE  UUID FECHA_MUESTRA  EDAD       SEXO  \
# 0      2023-09-27   NaN    2021-03-07  54.0  MASCULINO
# 1      2023-09-27   NaN    2021-06-16  46.0   FEMENINO
# 2      2023-09-27   NaN    2021-07-27  33.0   FEMENINO
# 3      2023-09-27   NaN    2021-10-22  26.0   FEMENINO
# 4      2023-09-27   NaN    2021-11-27  23.0  MASCULINO
# ...           ...   ...           ...   ...        ...
# 43167         NaT   NaN           NaT   NaN        NaN
# 43168         NaT   NaN           NaT   NaN        NaN
# 43169         NaT   NaN           NaT   NaN        NaN
# 43170         NaT   NaN           NaT   NaN        NaN
# 43171         NaT   NaN           NaT   NaN        NaN
#
#                        INSTITUCION  UBIGEO_PACIENTE DEPARTAMENTO_PACIENTE  \
# 0                GOBIERNO REGIONAL         240102.0                CALLAO
# 1      MINISTERIO DE SALUD - DIRIS         140126.0                  LIMA
# 2                  MUNICIPALIDADES         140140.0                  LIMA
# ...

# %%
#Contar los valores faltantes o nulos
df.isnull().sum()
# Out:
# FECHA_CORTE                5
# UUID                     179
# FECHA_MUESTRA              5
# EDAD                      15
# SEXO                       5
# INSTITUCION                5
# UBIGEO_PACIENTE            5
# DEPARTAMENTO_PACIENTE      5
# PROVINCIA_PACIENTE         5
# DISTRITO_PACIENTE          5
# DEPARTAMENTO_MUESTRA       5
# PROVINCIA_MUESTRA          5
# DISTRITO_MUESTRA           9
# TIPO_MUESTRA               5
# RESULTADO                  5
# dtype: int64

# %%
df.dropna(subset=['UUID'], inplace=True)
df
# Out:
#       FECHA_CORTE        UUID FECHA_MUESTRA  EDAD       SEXO  \
# 174    2023-09-27       823.0    2021-08-23  73.0   FEMENINO
# 175    2023-09-27       951.0    2022-11-30  60.0   FEMENINO
# 176    2023-09-27      1537.0    2022-07-22  57.0   FEMENINO
# 177    2023-09-27      1665.0    2021-04-12  60.0   FEMENINO
# 178    2023-09-27      1960.0    2021-03-19  65.0   FEMENINO
# ...           ...         ...           ...   ...        ...
# 43162  2023-09-27  41038499.0    2023-06-23   1.0   FEMENINO
# 43163  2023-09-27  41050617.0    2023-07-11   0.0   FEMENINO
# 43164  2023-09-27  41050656.0    2023-07-08   0.0   FEMENINO
# 43165  2023-09-27  41097262.0    2023-08-01   0.0  MASCULINO
# 43166  2023-09-27  41153327.0    2023-08-30   0.0   FEMENINO
#
#                        INSTITUCION  UBIGEO_PACIENTE DEPARTAMENTO_PACIENTE  \
# 174              GOBIERNO REGIONAL         250101.0               UCAYALI
# 175              GOBIERNO REGIONAL         250101.0               UCAYALI
# ...

# %%
df['EDAD'] = df['EDAD'].astype(int)

# %%
df['UUID'] = df['UUID'].astype(int)

# %%
df['UBIGEO_PACIENTE'] = df['UBIGEO_PACIENTE'].astype(int)

# %%
df
# Out:
#       FECHA_CORTE      UUID FECHA_MUESTRA  EDAD       SEXO  \
# 174    2023-09-27       823    2021-08-23    73   FEMENINO
# 175    2023-09-27       951    2022-11-30    60   FEMENINO
# 176    2023-09-27      1537    2022-07-22    57   FEMENINO
# 177    2023-09-27      1665    2021-04-12    60   FEMENINO
# 178    2023-09-27      1960    2021-03-19    65   FEMENINO
# ...           ...       ...           ...   ...        ...
# 43162  2023-09-27  41038499    2023-06-23     1   FEMENINO
# 43163  2023-09-27  41050617    2023-07-11     0   FEMENINO
# 43164  2023-09-27  41050656    2023-07-08     0   FEMENINO
# 43165  2023-09-27  41097262    2023-08-01     0  MASCULINO
# 43166  2023-09-27  41153327    2023-08-30     0   FEMENINO
#
#                        INSTITUCION  UBIGEO_PACIENTE DEPARTAMENTO_PACIENTE  \
# 174              GOBIERNO REGIONAL           250101               UCAYALI
# 175              GOBIERNO REGIONAL           250101               UCAYALI
# ...

# %%
df.isnull().sum()
# Out:
# FECHA_CORTE              0
# UUID                     0
# FECHA_MUESTRA            0
# EDAD                     3
# SEXO                     0
# INSTITUCION              0
# UBIGEO_PACIENTE          0
# DEPARTAMENTO_PACIENTE    0
# PROVINCIA_PACIENTE       0
# DISTRITO_PACIENTE        0
# DEPARTAMENTO_MUESTRA     0
# PROVINCIA_MUESTRA        0
# DISTRITO_MUESTRA         4
# TIPO_MUESTRA             0
# RESULTADO                0
# dtype: int64

# %%
df.dropna(subset=['EDAD'], inplace=True)

# %%
df.isnull().sum()
# Out:
# FECHA_CORTE              0
# UUID                     0
# FECHA_MUESTRA            0
# EDAD                     0
# SEXO                     0
# INSTITUCION              0
# UBIGEO_PACIENTE          0
# DEPARTAMENTO_PACIENTE    0
# PROVINCIA_PACIENTE       0
# DISTRITO_PACIENTE        0
# DEPARTAMENTO_MUESTRA     0
# PROVINCIA_MUESTRA        0
# DISTRITO_MUESTRA         4
# TIPO_MUESTRA             0
# RESULTADO                0
# dtype: int64

# %%
df.dropna(subset=['DISTRITO_MUESTRA'], inplace=True)

# %%
df.isnull().sum()
# Out:
# FECHA_CORTE              0
# UUID                     0
# FECHA_MUESTRA            0
# EDAD                     0
# SEXO                     0
# INSTITUCION              0
# UBIGEO_PACIENTE          0
# DEPARTAMENTO_PACIENTE    0
# PROVINCIA_PACIENTE       0
# DISTRITO_PACIENTE        0
# DEPARTAMENTO_MUESTRA     0
# PROVINCIA_MUESTRA        0
# DISTRITO_MUESTRA         0
# TIPO_MUESTRA             0
# RESULTADO                0
# dtype: int64

# %%
df
# Out:
#       FECHA_CORTE      UUID FECHA_MUESTRA  EDAD       SEXO  \
# 174    2023-09-27       823    2021-08-23    73   FEMENINO
# 175    2023-09-27       951    2022-11-30    60   FEMENINO
# 176    2023-09-27      1537    2022-07-22    57   FEMENINO
# 177    2023-09-27      1665    2021-04-12    60   FEMENINO
# 178    2023-09-27      1960    2021-03-19    65   FEMENINO
# ...           ...       ...           ...   ...        ...
# 43162  2023-09-27  41038499    2023-06-23     1   FEMENINO
# 43163  2023-09-27  41050617    2023-07-11     0   FEMENINO
# 43164  2023-09-27  41050656    2023-07-08     0   FEMENINO
# 43165  2023-09-27  41097262    2023-08-01     0  MASCULINO
# 43166  2023-09-27  41153327    2023-08-30     0   FEMENINO
#
#                        INSTITUCION  UBIGEO_PACIENTE DEPARTAMENTO_PACIENTE  \
# 174              GOBIERNO REGIONAL           250101               UCAYALI
# 175              GOBIERNO REGIONAL           250101               UCAYALI
# ...

# %%
sns.boxplot(data=df, x='EDAD')
# Out:
# <Axes: xlabel='EDAD'>

# %%
df['FECHA_MUESTRA'].max()
# Out:
# Timestamp('2023-09-11 00:00:00')

# %%
df['FECHA_MUESTRA'].min()
# Out:
# Timestamp('2020-02-10 00:00:00')

# %%
# Filtrar registros del año 2022
# Filtrar registros del año 2022
df_2022 = df[df['FECHA_MUESTRA'].dt.year == 2022]

# %%
df_2022
# Out:
#       FECHA_CORTE      UUID FECHA_MUESTRA  EDAD       SEXO  \
# 175    2023-09-27       951    2022-11-30    60   FEMENINO
# 176    2023-09-27      1537    2022-07-22    57   FEMENINO
# 179    2023-09-27      2251    2022-02-25    60   FEMENINO
# 180    2023-09-27      2296    2022-11-24    57  MASCULINO
# 181    2023-09-27      2427    2022-07-20    60   FEMENINO
# ...           ...       ...           ...   ...        ...
# 43122  2023-09-27  40537271    2022-12-22     0   FEMENINO
# 43123  2023-09-27  40538004    2022-12-24     0  MASCULINO
# 43124  2023-09-27  40539211    2022-12-29    47  MASCULINO
# 43131  2023-09-27  40607582    2022-04-13    52   FEMENINO
# 43139  2023-09-27  40715134    2022-12-13    29   FEMENINO
#
#                                    INSTITUCION  UBIGEO_PACIENTE  \
# 175                          GOBIERNO REGIONAL           250101
# 176                          GOBIERNO REGIONAL           250102
# ...

# %%
df_APURIMAC = df[df['DEPARTAMENTO_PACIENTE'] =='APURIMAC']

# %%
df_APURIMAC
# Out:
#       FECHA_CORTE      UUID FECHA_MUESTRA  EDAD       SEXO        INSTITUCION  \
# 1409   2023-09-27    351579    2022-11-24    52   FEMENINO  GOBIERNO REGIONAL
# 1413   2023-09-27    352975    2022-07-18    48   FEMENINO            ESSALUD
# 1449   2023-09-27    376556    2022-01-31    67  MASCULINO  GOBIERNO REGIONAL
# 2163   2023-09-27   1022596    2022-07-12    63  MASCULINO  GOBIERNO REGIONAL
# 3212   2023-09-27   1636313    2023-06-23    45  MASCULINO  GOBIERNO REGIONAL
# ...           ...       ...           ...   ...        ...                ...
# 42728  2023-09-27  37746005    2021-06-18    42  MASCULINO  GOBIERNO REGIONAL
# 42929  2023-09-27  38700462    2022-02-02    67  MASCULINO  GOBIERNO REGIONAL
# 43100  2023-09-27  40357031    2022-11-18    44  MASCULINO  GOBIERNO REGIONAL
# 43128  2023-09-27  40565583    2023-08-28     0   FEMENINO  GOBIERNO REGIONAL
# 43162  2023-09-27  41038499    2023-06-23     1   FEMENINO            ESSALUD
#
# ...

# %%
df_apurimac_femenino = df[(df['DEPARTAMENTO_PACIENTE'] == 'APURIMAC') & (df['SEXO'] == 'FEMENINO')]
df_apurimac_femenino
# Out:
#       FECHA_CORTE      UUID FECHA_MUESTRA  EDAD      SEXO        INSTITUCION  \
# 1409   2023-09-27    351579    2022-11-24    52  FEMENINO  GOBIERNO REGIONAL
# 1413   2023-09-27    352975    2022-07-18    48  FEMENINO            ESSALUD
# 4174   2023-09-27   2094927    2022-07-17    47  FEMENINO  GOBIERNO REGIONAL
# 4205   2023-09-27   2110722    2022-01-21    55  FEMENINO  GOBIERNO REGIONAL
# 4593   2023-09-27   2307541    2021-08-18    49  FEMENINO  GOBIERNO REGIONAL
# ...           ...       ...           ...   ...       ...                ...
# 42356  2023-09-27  35968021    2022-07-06    27  FEMENINO  GOBIERNO REGIONAL
# 42443  2023-09-27  36025680    2021-08-11    17  FEMENINO  GOBIERNO REGIONAL
# 42495  2023-09-27  36111177    2021-04-14    51  FEMENINO  GOBIERNO REGIONAL
# 43128  2023-09-27  40565583    2023-08-28     0  FEMENINO  GOBIERNO REGIONAL
# 43162  2023-09-27  41038499    2023-06-23     1  FEMENINO            ESSALUD
#
# ...

# %%
#A propuesta del grupo realizar una consulta y justificar porque se debería realizar la misma
df_INSTITUCION = df[df['INSTITUCION'] =='GOBIERNO REGIONAL']
df_INSTITUCION
# Realizamos esta consulta con el objetivo de identificar a los individuos que no cuentan con los recursos necesarios.
# La información obtenida nos permitirá analizar y entender mejor las áreas donde se requiere una mejora en el suministro de recursos.
# Este análisis es crucial para garantizar que todos los recursos estén disponibles de manera equitativa y eficiente,
# contribuyendo a un mejor manejo de los recursos y a una mayor satisfacción de las necesidades de todos los involucrados.
# Out:
#       FECHA_CORTE      UUID FECHA_MUESTRA  EDAD       SEXO        INSTITUCION  \
# 174    2023-09-27       823    2021-08-23    73   FEMENINO  GOBIERNO REGIONAL
# 175    2023-09-27       951    2022-11-30    60   FEMENINO  GOBIERNO REGIONAL
# 176    2023-09-27      1537    2022-07-22    57   FEMENINO  GOBIERNO REGIONAL
# 177    2023-09-27      1665    2021-04-12    60   FEMENINO  GOBIERNO REGIONAL
# 178    2023-09-27      1960    2021-03-19    65   FEMENINO  GOBIERNO REGIONAL
# ...           ...       ...           ...   ...        ...                ...
# 43152  2023-09-27  40906982    2023-04-26     5  MASCULINO  GOBIERNO REGIONAL
# 43154  2023-09-27  40910282    2023-05-09    36  MASCULINO  GOBIERNO REGIONAL
# 43156  2023-09-27  40931518    2023-06-20     0  MASCULINO  GOBIERNO REGIONAL
# 43165  2023-09-27  41097262    2023-08-01     0  MASCULINO  GOBIERNO REGIONAL
# 43166  2023-09-27  41153327    2023-08-30     0   FEMENINO  GOBIERNO REGIONAL
#
# ...
